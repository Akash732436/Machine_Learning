# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/drive/MyDrive/Inter/elon.jpg')

# %%
img.shape
# Out:
# (720, 480, 3)

# %%
img[0][0]
# Out:
# array([184, 189, 188], dtype=uint8)

# %%
cv2_imshow(img)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=480x720 at 0x7F666453E5D0>

# %%
rev_img=img[:,:,::-1]

# %%
plt.imshow(img)
plt.axis(False)
# Out:
# (-0.5, 479.5, 719.5, -0.5)

# %%
plt.imshow(rev_img)

# %%
def show_image(img_arr):
  rgb_arr=cv2.cvtColor(img_arr,cv2.COLOR_BGR2RGB)
  plt.imshow(rgb_arr)
  plt.axis(False)

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
show_image(gray_img)

# %%
inverted_img=255-gray_img
show_image(inverted_img)

# %%
blur_img=cv2.GaussianBlur(inverted_img,(111,111),0)
show_image(blur_img)

# %%
sketch=cv2.divide(blur_img,inverted_img,scale=256.0)
show_image(sketch)

# %%
sketch2=sketch[:,::-1]

# %%
cv2_imshow(sketch2)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=480x720 at 0x7F664E09FF90>
